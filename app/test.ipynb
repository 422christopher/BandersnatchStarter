# %%
import data
import graph

# %%
my_table = data.Database("Test")
my_table.reset()
my_table.seed(1000)

# %%
df = my_table.dataframe()

# %%
df = df[["Level", "Rarity", "Damage", "Health", "Energy", "Sanity"]]
df
# Out:
#      Level  Rarity   Damage  Health  Energy  Sanity
# 0       15  Rank 4  15d10+2  146.20  150.43  148.11
# 1       14  Rank 0   14d2+1   28.63   27.92   28.41
# 2       17  Rank 3     17d8  134.14  132.06  135.54
# 3        5  Rank 0    5d2+4    9.44    9.93    9.44
# 4       11  Rank 0   11d2+2   22.26   22.75   22.58
# ..     ...     ...      ...     ...     ...     ...
# 995      3  Rank 1      3d4   12.81   11.39   10.17
# 996     11  Rank 1     11d4   44.07   43.90   43.79
# 997     13  Rank 1   13d4+1   50.11   53.13   51.37
# 998      7  Rank 0      7d2   13.18   14.34   14.73
# 999     14  Rank 3     14d8  111.08  108.09  112.51
#
# [1000 rows x 6 columns]

# %%
graph.chart(df, 'Level', 'Energy', 'Rarity')
# Out:
# alt.Chart(...)

# %%
print(type(df.Level))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.count()
# Out:
# Level     1000
# Rarity    1000
# Damage    1000
# Health    1000
# Energy    1000
# Sanity    1000
# dtype: int64
