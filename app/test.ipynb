# %%
import data
import graph

# %%
my_table = data.Database("Test")
my_table.seed(1000)

# %%
df = my_table.dataframe()

# %%
df = df[["Level", "Rarity", "Damage", "Health", "Energy", "Sanity"]]
df
# Out:
#       Level  Rarity   Damage  Health  Energy  Sanity
# 0         4  Rank 2      4d6   25.16   21.23   23.71
# 1        10  Rank 4  10d10+2   98.14   98.83  100.87
# 2         5  Rank 0    5d2+1   10.31    9.05   10.52
# 3         7  Rank 1    7d4+2   28.96   28.19   27.49
# 4         3  Rank 1    3d4+4   12.08   11.22   11.76
# ...     ...     ...      ...     ...     ...     ...
# 2995     11  Rank 4    11d10  107.07  108.76  110.39
# 2996      3  Rank 0    3d2+3    6.96    6.27    5.80
# 2997      3  Rank 3    3d8+1   26.31   24.87   25.68
# 2998      2  Rank 5   2d12+1   21.05   22.86   23.67
# 2999      7  Rank 1    7d4+3   28.22   28.42   26.33
#
# [3000 rows x 6 columns]

# %%
graph.chart(df, 'Level', 'Energy', 'Rarity')
# Out:
# alt.Chart(...)

# %%
print(type(df.Level))
# Out:
# <class 'pandas.core.series.Series'>
